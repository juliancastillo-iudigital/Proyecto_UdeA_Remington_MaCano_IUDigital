# %% [markdown]
# ---
# <h1 align="center"> <b> Evaluación de las políticas públicas asociadas al fortalecimiento de las unidades productivas agrícolas de los corregimientos de Medellín.</b> </h1>
#
#
# <div align="left">
# <p><img alt="IUDigital" height="100px" src="https://raw.githubusercontent.com/juliancastillo-iudigital/Proyecto_UdeA_Remington_MaCano_IUDigital/main/Images/iudigital.png" align="left" hspace="10px" vspace="0px"></p>
# </div>
# <div> </div>
#
# <div align="right">
# <p><img alt="Uniremington" height="100px" src="https://raw.githubusercontent.com/juliancastillo-iudigital/Proyecto_UdeA_Remington_MaCano_IUDigital/main/Images/Uniremington.jpg" align="right" hspace="10px" vspace="10px"></p>
# </div>
# <div> </div>
# <div align="left">
# <p><img alt="MaCano" height="100px" src="https://raw.githubusercontent.com/juliancastillo-iudigital/Proyecto_UdeA_Remington_MaCano_IUDigital/main/Images/mcano.jpg" align="left" hspace="10px" vspace="0px"></p>
# </div>
# <div> </div>
#
# <div align="right">
# <p><img alt="UdeA" height="100px" src="https://raw.githubusercontent.com/juliancastillo-iudigital/Proyecto_UdeA_Remington_MaCano_IUDigital/main/Images/udea.png" align="right" hspace="10px" vspace="10px"></p>
# </div>
# <div> </div>
#
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <p>
# <h1 align="center"> <b> Modelo Analítico V1</b> </h1>
# <hr size=10 noshade color="red">
# </p>
# <p>
# <img alt="CC" height="70px" src="https://creativecommons.org/images/deed/cc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="Attribution" height="70px" src="https://creativecommons.org/images/deed/attribution_icon_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="NC" height="70px" src="https://creativecommons.org/images/deed/nc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="SA" height="70px" src="https://creativecommons.org/images/deed/sa_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <br></br><br></br>
# </p>
#
# <hr size=1 noshade color="black">
# <div align="right">
# <h1> Investigadora Principal: Lina María Bastidas Orrego</h1>
# <h2><a href="mailto:lina.bastidas@uniremington.edu.co">✉ Lina María Bastidas Orrego </a></h2>
# <hr size=1 noshade color="black">
#
# <hr size=1 noshade color="black">
# <div align="right">
# <h1> CoInvestigador 1: Yony Fernando Ceballos</h1>
# <h2><a href="mailto:yony.ceballos@udea.edu.co">✉ Yony Fernando Ceballos </a></h2>
# <hr size=1 noshade color="black">
#
# <hr size=1 noshade color="black">
# <div align="right">
# <h1> CoInvestigador 2: Julian Andres Castillo Grisales</h1>
# <h2><a href="mailto:julian.castillo@iudigital.edu.co">✉ Julian Andres Castillo Grisales</a></h2>
# <hr size=1 noshade color="black">
#
# <hr size=1 noshade color="black">
# <div align="right">
# <h1> CoInvestigador 3: Natalia Isabel Jaramillo Gomez</h1>
# <h2><a href="mailto:nataliaisabeljaramillogomez@fumc.edu.co">✉ Natalia Isabel Jaramillo Gomez</a></h2>
# <hr size=1 noshade color="black">
#
#
# <hr size=5 noshade color="blue">
#
# </div>
#
# <br>
#
#
# ---

# %% [markdown]
# #**Resumen del Proyecto**
#
# Medellín cuenta con una importante demanda de alimentos frescos, pero al mismo tiempo el 70% de su territorio es rural, donde no sólo ofrece servicios ambientales, sino que produce alrededor de 29.000 toneladas/año de alimentos, lo que lo convierte en una excelente alternativa para proveer alimentos “0 kilómetros” a la ciudad.
#
# Esta propuesta de investigación pretende mediante la combinación de dos herramientas, hacer una evaluación de las políticas públicas asociadas al fortalecimiento de las unidades productivas agrícola de los corregimientos de Medellín. Por tanto, se realizará una evaluación de percepción junto con un modelo de simulación para evaluar diversas políticas identificadas en el análisis exploratorio, con el ánimo de realizar sugerencias de política pública al municipio, de acuerdo a la percepción de la población, la producción y el cambio en la tenencia de la tierra dedicada a la actividad agrícola. Dada la metodología propuesta, la selección del paradigma de simulación se hará posterior a la revisión del estado del arte.
#
# Este proyecto se enmarca en la línea de investigación de poder y organización, donde se precisa la importancia de estas unidades agrícolas en la estructura productiva de la ciudad.

# %% [markdown]
# # **Objetivos**
#
# *   Objetivo General
# >Diseñar un modelo para la evaluación de las políticas públicas agrícolas municipales y su impacto económico en los corregimientos de Medellín, enmarcado en el Acuerdo 048 de 2014.
#
# *   Objetivos específicos
# >*   Identificar las políticas públicas enfocadas al desarrollo agrícola, de acuerdo a las administraciones municipales.
# >*   Desarrollar el modelo de simulación para representar el desarrollo agrícola de los corregimientos de Medellín.
# >*   Identificar la percepción de la población rural sobre el impacto de las políticas agrícolas
# >*   Analizar los resultados de las variables microeconómicas que se utilizaran para evaluar las políticas públicas que inciden en el desarrollo agrícola y económico de los corregimientos en diferentes escenarios.

# %% [markdown]
# # **Modelos Conceptuales**
#
# Modelos conceptuales: se debe realizar la construcción de modelos conceptuales con las diferentes actividades, es decir, por medio del modelo permite trabajar con más profundidad la definición básica, la cual se basa en las actividades para poder realizar el sistema planteado.

# %% [markdown]
# # **Fuentes de Datos**
#
# La metodología propuesta se soporta en diversas fuentes de información. Primero, fuentes primarias representadas por el marco legal y la política pública, así como entrevistas a líderes locales en los corregimientos. Las fuentes de información secundarias corresponden a documentos y entrevistas en las que se expresa el análisis, opinión o percepción de individuos, grupos de personas y organizaciones como ONGs, grupos académicos y organizaciones civiles.  A través del trabajo exploratorio llevado a cabo para la elaboración de esta propuesta y de la delimitación de su alcance, se han identificado algunas de las personas y organizaciones que podrían contribuir con la información necesaria para alcanzar los objetivos propuestos, por lo tanto, se tomará información histórica y detallada de los planes de ordenamiento territorial del Municipio de Medellín, información catastral de densificación de construcciones y reportes de la Subsecretaría de Desarrollo Rural de Medellín.

# %% [markdown]
# ## **Obtención de información geográfica**
#
# Portal Geográfico - GEO medellin
# *   [https://www.medellin.gov.co/geomedellin/](https://www.medellin.gov.co/geomedellin/)
#
# Mapas Medellín, una plataforma geográfica que les permite a los ciudadanos consultar y analizar la información geográfica del Distrito Especial de Medellín.
#
# ## **Obtención de información catastral**
#
# Estadísticas catastrales Medellín
# *   [https://www.medellin.gov.co/es/centro-documental/estadisticas-catastrales-medellin/](https://www.medellin.gov.co/es/centro-documental/estadisticas-catastrales-medellin/)
#
# Estadísticas catastrales Medellín es un subportal en donde se encuentran predios, base gravable por comuna, cantidad de predios por uso predial y estratos predominantes, entre otros.
#
# https://www.medellin.gov.co/es/centro-documental/estadisticas-catastrales-medellin/

# %% [markdown]
# ## **Unión de Capas y Datos**
#
# Con el uso de QGIS el cual es un Sistema de Información Geográfica de software libre y de código abierto para plataformas GNU/Linux, Unix, Mac OS, Microsoft Windows y Android. El procedimiento para realizar la unión de las capas se realiza mediante el uso de la herramienta “Unir Atributos por localización” el cual combina dos capas de acuerdo con atributos de ubicación, esto se hace para todas las capas obtenidas y mediante la definición de una capa inicial la cual es el primer eslabón de la cadena de unión de atributos, es decir, cada vez que se realiza el proceso de unión se crea una nueva capa con los datos anteriores y nuevos adicionales de la unión, y así se va conformando secuencialmente una sola capa con todos los datos de las políticas públicas relacionadas a los predios rurales, esta capa resultante es inicialmente la definida por los predios rurales del Municipio de Medellín y con base en estos se comienza a unir la información mediante el siguiente predicado geométrico para todos los objetos geográficos mediante la intersección y de adición de campos mediante el tipo de unión de uno a uno, es decir, solo toma un atributo en el campo de la capa de lotes y adiciona en caso de intersecar con este los datos de la capa adicionada. A continuación, se muestra una imagen del proceso realizado.
#
# ![](https://raw.githubusercontent.com/juliancastillo-iudigital/Proyecto_UdeA_Remington_MaCano_IUDigital/main/Images/ejemplo1_unionatributos.png)
#
# Definición de predio: Es un inmueble no separado por otro predio público o privado, con o sin construcciones y/o edificaciones, perteneciente a personas naturales o jurídicas. El predio mantiene su unidad, aunque esté atravesado por corrientes de agua pública. * Se incluyen en esta definición los baldíos, los ejidos, los vacantes, los resguardos indígenas, las reservas naturales, las tierras de las comunidades negras, la propiedad horizontal, los condominios (unidades inmobiliarias cerradas), las multipropiedades, las parcelaciones, los parques cementerios, los bienes de uso público y todos aquellos otros que se encuentren individualizados con una matrícula inmobiliaria, así como las mejoras por edificaciones en terreno ajeno.

# %% [markdown]
# ## **Detalle de la información obtenida y su uso en el proyecto**
#
# Para cada uno de los campos aquí descritos se define un valor dicotómico en donde de acuerdo con la definición de sus valores se asigna un valor VERDADERO o FALSO, en donde el valor positivo permite del desarrollo agropecuario y el contrario no lo permite. Como primera aproximación se tratará de crear un modelo de agrupación o clasificación zonal en donde las características de la mayoría determinaran el comportamiento de los demás predios, es decir, si en un clúster o sector en donde la mayoría se comporte o se orienten con el desarrollo agropecuario los demás predios en dicho clúster también podrán comportarse.
# Estas nuevas clasificaciones nos podrán detallar si las políticas actuales detalladas por el POT vigente se encuentran correctamente asignadas o deben ser mejoradas. Con los resultados se obtendrá gracias a los datos de área de suelo un valor propuesto de área posible de acción agropecuaria para así fortalecer la autosostenibilidad de la ciudad de Medellín.
# Los datos se describen a continuación incluyendo la respectiva tabla de valores dicotómicos.

# %% [markdown]
# ---

# %% [markdown]
# ### **Clasificación Del Suelo**
#
# *   Clasificación Del Suelo: detalle de la categoría del suelo
# >*   Suelos suburbanos propiamente dichos: suelos que corresponden con expansión del suelo urbano para vivienda.
# >*   Áreas para la localización de equipamientos: suelos que corresponden para la ubicación de actuales y nuevos equipamientos, por ejemplo, escuelas, centros de atención, estaciones de policía entre otros.
# >*   Centros poblados rurales: suelos donde la concentración rural de viviendas es mayor.
# >*   Áreas destinadas a la parcelación de vivienda campestre: suelos destinados a futuras parcelaciones de vivienda.
# >*   Otros: N/A, suelos sin clasificación, en su mayoría se definen como suelos de cultivo o protección.
#
# ### **Tabla Dicotómica Clasificación Del Suelo**
#
# | CS_ClasificacionSuelo                                     | CS_TF     |
# |-----------------------------------------------------------|-----------|
# | Suelos suburbanos propiamente dichos                      | FALSO     |
# | Áreas destinadas a la parcelación de   vivienda campestre | FALSO     |
# | Áreas para la localización de   equipamientos             | FALSO     |
# | Centros poblados rurales                                  | FALSO     |
# | N/A                                                       | VERDADERO |
#
# ---

# %% [markdown]
# ### **Equipamientos**
#
# *   Equipamientos: excepto de otros, los equipamientos son predios en donde existen construcciones destinadas al funcionamiento y/o bienestar de la comunidad.
# >*   Equipamientos Comunitarios
# >*   Equipamiento de Educación
# >*   Equipamientos de Culto
# >*   Equipamientos para la Fuerza Pública
# >*   Equipamientos Sanitarios
# >*   Equipamiento de Salud
# >*   Equipamientos para la prestación de los servicios públicos
# >*   Equipamiento de Recreación y Deporte
# >*   Equipamientos de Justicia Cercana al Ciudadano
# >*   Equipamiento de Asistencia Social
# >*   Equipamientos Culturales
# >*   Equipamientos para el Transporte
# >*   Equipamientos Institucionales Municipales
# >*   Equipamiento para la Administración de Justicia
# >*   Uso dotacional sin equipamiento construido
# >*   Equipamiento de Prevención y atención de desastres
# >*   Otros: Suelos donde no existen equipamientos
#
# ### **Tabla Dicotómica Equipamientos**
#
# | EQ_Equipamientos                                             | EQ_TF     |
# |--------------------------------------------------------------|-----------|
# | Equipamiento de Asistencia Social                            | FALSO     |
# | Equipamiento de Educación                                    | FALSO     |
# | Equipamiento de Prevención y atención de  desastres          | FALSO     |
# | Equipamiento de Recreación y Deporte                         | FALSO     |
# | Equipamiento de Salud                                        | FALSO     |
# | Equipamiento para la Administración de   Justicia            | FALSO     |
# | Equipamientos Comunitarios                                   | FALSO     |
# | Equipamientos Culturales                                     | FALSO     |
# | Equipamientos de Culto                                       | FALSO     |
# | Equipamientos de Justicia Cercana al   Ciudadano             | FALSO     |
# | Equipamientos Institucionales Municipales                    | FALSO     |
# | Equipamientos para el Transporte                             | FALSO     |
# | Equipamientos para la Fuerza Pública                         | FALSO     |
# | Equipamientos para la prestación de los   servicios públicos | FALSO     |
# | Equipamientos Sanitarios                                     | FALSO     |
# | Uso dotacional sin equipamiento   construido                 | FALSO     |
# | N/A                                                          | VERDADERO |
#
# ---

# %% [markdown]
# ### **Hidrografía**
#
# *   Hidrografía: descripción de los drenajes que cruzan por los predios.
# >*   Drenajes y corredores secundarios: predios por los cuales cruza uno o múltiples drenajes secundarios
# >*   Drenajes y corredores principales: predios por los cuales cruza uno o múltiples drenajes principales.
# >*   Otros: N/A, predios por donde no cruza ningún tipo de drenaje
#
# ### **Tabla Dicotómica Hidrografía**
#
# | H_Hidrografia                     | H_TF      |
# |-----------------------------------|-----------|
# | Drenajes y corredores principales | VERDADERO |
# | Drenajes y corredores secundarios | VERDADERO |
# | N/A                               | FALSO     |
#
# ---

# %% [markdown]
# ### **Planes Parciales**
#
# *   Planes Parciales: detalle de los proyectos de proyección de ciudad bajo el esquema de plan parcial.
# >*   Áreas de Preservación de Infraestructuras y del Sistema Público y Colectivo
# >*   Desarrollo en Suelo Expansión
# >*   Desarrollo en Suelo Urbano
# >*   Mejoramiento Integral
# >*   Mejoramiento Integral en Suelo Expansión
# >*   Mejoramiento Integral en suelo urbano
# >*   Otro: N/A, sin categoría o detalle de plan parcial
#
# ### **Tabla Dicotómica Planes Parciales**
#
# | PP_PlanParcial                                        | PP_Categoria                                                                  | PP_TF     |
# |-------------------------------------------------------|-------------------------------------------------------------------------------|-----------|
# | Planes de Legalización y Regularización   Urbanística | Mejoramiento Integral en suelo urbano                                         | FALSO     |
# | Planes de Legalización y Regularización   Urbanística | Mejoramiento Integral                                                         | FALSO     |
# | Planes Maestros                                       | Áreas de Preservación de Infraestructuras y del Sistema Público y   Colectivo | FALSO     |
# | Planes Parciales                                      | Desarrollo en Suelo Urbano                                                    | FALSO     |
# | Planes Parciales                                      | Mejoramiento Integral en Suelo Expansión                                      | FALSO     |
# | Planes Parciales                                      | Desarrollo en Suelo Expansión                                                 | FALSO     |
# | N/A                                                   | N/A                                                                           | VERDADERO |
#
# ---

# %% [markdown]
# ### **Planificación Complementaria**
#
# *   Planificación Complementaria (AIE: Área de Intervención Estratégica)
# >*   AIE MEDBorde Urbano Rural
# >*   AIE Transversalidades
# >*   Distritos Rurales Campesinos - Corregimiento San Antonio de Prado
# >*   Distritos Rurales Campesinos - Corregimiento San Cristóbal
# >*   Distritos Rurales Campesinos - Corregimiento San Sebastián de Palmitas
# >*   Distritos Rurales Campesinos - Corregimiento Santa Elena
# >*   Proyecto urbano integral del ámbito ladera suroccidental
# >*   Unidades de Planificación Rural para la Sostenibilidad Ambiental
# >*   Unidades de Planificación Rural para el Reordenamiento y Mejoramiento
# >*   Unidades de Planificación Rural para la Transformación
# >*   Otros: N/A, suelos sin planificación complementaria
#
# ### **Tabla Dicotómica Planificación Complementaria**
#
# |     PC_PlanificacionComplementaria                      |     PC_Categorias                                                               |     PC_TF        |
# |---------------------------------------------------------|---------------------------------------------------------------------------------|------------------|
# |     Distritos   Rurales Campesinos                      |     Distritos   Rurales Campesinos - Corregimiento Santa Elena                  |     VERDADERO    |
# |     Distritos   Rurales Campesinos                      |     Distritos   Rurales Campesinos - Corregimiento San Antonio de Prado         |     VERDADERO    |
# |     Distritos   Rurales Campesinos                      |     Distritos   Rurales Campesinos - Corregimiento San Cristóbal                |     VERDADERO    |
# |     Distritos   Rurales Campesinos                      |     Distritos   Rurales Campesinos - Corregimiento San Sebastián de Palmitas    |     VERDADERO    |
# |     Macroproyectos                                      |     AIE   MEDBorde Urbano Rural                                                 |     VERDADERO    |
# |     Macroproyectos                                      |     AIE   Transversalidades                                                     |     VERDADERO    |
# |     Proyectos   Urbanos Integrales del Ámbito Ladera    |     Proyecto   urbano integral del ámbito ladera suroccidental                  |     FALSO        |
# |     Unidades   de Planificación Rural                   |     Unidades   de Planificación Rural para la Sostenibilidad Ambiental          |     FALSO        |
# |     Unidades   de Planificación Rural                   |     Unidades   de Planificación Rural para el Reordenamiento y Mejoramiento     |     VERDADERO    |
# |     Unidades   de Planificación Rural                   |     Unidades   de Planificación Rural para la Transformación                    |     FALSO        |
# |     N/A                                                 |     N/A                                                                         |     VERDADERO    |
#
# ---

# %% [markdown]
# ### **Protección y Producción**
#
# *   Protección y Producción: suelos con énfasis en protección y producción
# >*   Áreas Mineras en Transición
# >*   Producción agrícola
# >*   Producción agroforestal
# >*   Producción agropecuaria
# >*   Producción forestal
# >*   Otros: N/A, suelos sin clasificación de producción o producción
#
# ### **Tabla Dicotómica Protección y Producción**
#
# |     PP_ProteccionProduccion                     |     PP_Categoria                     |     PP_Subcategoria                  |     PP_TF        |
# |-------------------------------------------------|--------------------------------------|--------------------------------------|------------------|
# |     Áreas   de protección para la producción    |     Agroforestal                     |     Producción   agroforestal        |     VERDADERO    |
# |     Áreas   de protección para la producción    |     Agrícola                         |     Producción   agrícola            |     VERDADERO    |
# |     Áreas   de protección para la producción    |     Agropecuario                     |     Producción   agropecuaria        |     VERDADERO    |
# |     Áreas   de protección para la producción    |     Forestal   Productor             |     Producción   forestal            |     FALSO        |
# |     Áreas   de protección para la producción    |     Áreas   Mineras en Transición    |     Áreas   Mineras en Transición    |     FALSO        |
# |     N/A                                         |     N/A                              |     N/A                              |     VERDADERO    |
#
# ---

# %% [markdown]
# ### **Tratamientos Rurales**
#
# *   Tratamientos Rurales: suelos con proyección de tratamiento de orientación rural para el desarrollo, conservación, consolidación o producción.
# >*   Áreas de Preservación de Infraestructuras y del Sistema Público y Colectivo
# >*   Conservación
# >*   Conservación por alto riesgo no mitigable
# >*   Consolidación Suburbana
# >*   Desarrollo
# >*   Generación de actividades rurales sostenibles
# >*   Mejoramiento Integral
# >*   Restauración de actividades rurales
# >*   Transición a protección
# >*   Otros: N/A, suelos sin descripción o clasificación
#
# ### **Tabla Dicotómica Tratamientos Rurales**
#
# | TR_TratamientosRurales                                                        | TR_Categoria                                                                  | TR_TF     |
# |-------------------------------------------------------------------------------|-------------------------------------------------------------------------------|-----------|
# | Áreas de Preservación de Infraestructuras   y del Sistema Público y Colectivo | Áreas de Preservación de Infraestructuras y del Sistema Público y   Colectivo | FALSO     |
# | Conservación                                                                  | Conservación                                                                  | VERDADERO |
# | Conservación por alto riesgo no mitigable                                     | Conservación por alto riesgo no mitigable                                     | FALSO     |
# | Consolidación Suburbana Nivel 1                                               | Consolidación Suburbana                                                       | FALSO     |
# | Consolidación Suburbana Nivel 2                                               | Consolidación Suburbana                                                       | FALSO     |
# | Consolidación Suburbana Nivel 3                                               | Consolidación Suburbana                                                       | FALSO     |
# | Consolidación Suburbana Nivel 4                                               | Consolidación Suburbana                                                       | FALSO     |
# | Desarrollo en Suelo Expansión                                                 | Desarrollo                                                                    | FALSO     |
# | Generación de actividades rurales   sostenibles                               | Generación de actividades rurales sostenibles                                 | VERDADERO |
# | Mejoramiento Integral                                                         | Mejoramiento Integral                                                         | FALSO     |
# | Mejoramiento Integral en Suelo Expansión                                      | Mejoramiento Integral                                                         | FALSO     |
# | Restauración de actividades rurales                                           | Restauración de actividades rurales                                           | VERDADERO |
# | Transición a protección                                                       | Transición a protección                                                       | FALSO     |
# | N/A                                                                           | N/A                                                                           | VERDADERO |
#
# ---

# %% [markdown]
# ### **Usos Rurales**
#
# *   Usos Rurales: clasificación del POT para el uso del suelo
# >*   Agrícola
# >*   Agroforestal
# >*   Agropecuario
# >*   Áreas Mineras en Transición
# >*   Dotacional y de servicios
# >*   Forestal Productor
# >*   Forestal Protector
# >*   Mixto urbano rural
# >*   Servicios e Industria
# >*   Otros: N/A, suelos sin clasificación de suelo rural
#
# ### **Tabla Dicotómica Usos Rurales**
#
# |     UR_UsosRurales                   |     UR_UsosRuralesCategoria                     |     UR_UsosRuralesSubategoria        |     UR_TF        |
# |--------------------------------------|-------------------------------------------------|--------------------------------------|------------------|
# |     Agrícola                         |     Áreas   de protección para la producción    |     Producción   agrícola            |     VERDADERO    |
# |     Agroforestal                     |     Áreas   de protección para la producción    |     Producción   agroforestal        |     VERDADERO    |
# |     Agropecuario                     |     Áreas   de protección para la producción    |     Producción   agropecuaria        |     VERDADERO    |
# |     Áreas   Mineras en Transición    |     Áreas   de protección para la producción    |     Áreas   Mineras en Transición    |     FALSO        |
# |     Dotacional   y de servicios      |     N/A                                         |     N/A                              |     FALSO        |
# |     Forestal   Productor             |     Áreas   de protección para la producción    |     Producción   forestal            |     FALSO        |
# |     Forestal   Protector             |     N/A                                         |     N/A                              |     FALSO        |
# |     Mixto   urbano rural             |     N/A                                         |     N/A                              |     VERDADERO    |
# |     Servicios   e Industria          |     N/A                                         |     N/A                              |     FALSO        |
# |     N/A                              |     N/A                                         |     N/A                              |     VERDADERO    |
#
# ---

# %% [markdown]
# ### **Zonas de Protección**
#
# *   Zonas De Protección: zonas cuyo uso de suelo no puede ser cambiado de acuerdo con el POT
# >*   Áreas de conservación y protección ambiental
# >*   Áreas de protección para la producción
# >*   Áreas de Amenaza y Riesgo
#
# ### **Tabla Dicotómica Zonas de Protección**
#
# |     ZP_ZonasProteccion                                |     ZP_Categoria                                                      |     ZP_Subcategoria                                                         |     ZP_TF        |
# |-------------------------------------------------------|-----------------------------------------------------------------------|-----------------------------------------------------------------------------|------------------|
# |     Áreas   de Amenaza y Riesgo                       |     Áreas   de amenaza alta                                           |     Amenaza   alta por movimientos en masa                                  |     FALSO        |
# |     Áreas   de Amenaza y Riesgo                       |     Zona   con condiciones de riesgo                                  |     Zona   con condiciones de riesgo                                        |     FALSO        |
# |     Áreas   de Amenaza y Riesgo                       |     Áreas   de amenaza alta                                           |     Amenaza   alta por Inundación y avenida torrencial                      |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   protegidas                                                |     Reserva   Forestal Protectora Río Nare                                  |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   de interés estratégico - Sistema Hidrográfico             |     Cuencas   abastecedoras de acueductos                                   |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   de interés estratégico - Sistema Hidrográfico             |     Retiros   a corrientes hídricas                                         |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   de interés estratégico - Sistema Orográfico               |     Cerros   y cadenas montañosas estructurantes                            |     VERDADERO    |
# |     Áreas   de conservación y protección ambiental    |     Áreas   de interés estratégico - Red de Conectividad Ecológica    |     Red   de conectividad ecológica                                         |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   de interés estratégico - Sistema Hidrográfico             |     Humedales   y Lagunas                                                   |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   de interés estratégico - Sistema Hidrográfico             |     Cuencas   hidrográficas de orden cero                                   |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   protegidas                                                |     Reserva   Natural de la Sociedad Civil Montevivo                        |     FALSO        |
# |     Áreas   de conservación y protección ambiental    |     Áreas   protegidas                                                |     Distrito   de Manejo Integrado Divisoria Valle de Aburrá - Río Cauca    |     VERDADERO    |
# |     Áreas   de protección para la producción          |     Producción   agrícola                                             |     Agrícola                                                                |     VERDADERO    |
# |     Áreas   de protección para la producción          |     Producción   agroforestal                                         |     Agroforestal                                                            |     VERDADERO    |
# |     Áreas   de protección para la producción          |     Producción   agropecuaria                                         |     Agropecuario                                                            |     VERDADERO    |
# |     Áreas   de protección para la producción          |     Producción   forestal                                             |     Forestal   Productor                                                    |     FALSO        |
# |     Áreas   de protección para la producción          |     Áreas   Mineras en Transición                                     |     Transición   a protección                                               |     FALSO        |
# |     N/A                                               |     N/A                                                               |     N/A                                                                     |     VERDADERO    |
#
# ---

# %% [markdown]
# ### **Zonas de Riesgo**
#
# *   Zonas De Riesgo: zonas en donde existe un riesgo para la adecuación o transformación del suelo
# >*   Zona con condiciones de riesgo por avenidas torrenciales
# >*   Zona con condiciones de riesgo por inundaciones
# >*   Zona con condiciones de riesgo por movimientos en masa
# >*   Zona de alto riesgo no mitigable por avenidas torrenciales
# >*   Zona de alto riesgo no mitigable por movimientos en masa
#
# ### **Tabla Dicotómica Zonas de Riesgo**
#
# |     R_Riesgo                       |     R_Descripcion                                                   |     R_TipoAmenaza              |     R_Categoria                    |     R_Subcategoria                      |     R_TF         |
# |------------------------------------|---------------------------------------------------------------------|--------------------------------|------------------------------------|-----------------------------------------|------------------|
# |     Alto   riesgo no mitigable     |     Zona   de alto riesgo no mitigable por movimientos en masa      |     Movimientos   en masa      |     Áreas   de Amenaza y Riesgo    |     Zona   de riesgo no mitigable       |     FALSO        |
# |     Alto   riesgo no mitigable     |     Zona   de alto riesgo no mitigable por avenidas torrenciales    |     Avenidas   Torrenciales    |     Áreas   de Amenaza y Riesgo    |     Zona   de riesgo no mitigable       |     FALSO        |
# |     Con   condiciones de riesgo    |     Zona   con condiciones de riesgo por movimientos en masa        |     Movimientos   en masa      |     Áreas   de Amenaza y Riesgo    |     Zona   con condiciones de riesgo    |     FALSO        |
# |     Con   condiciones de riesgo    |     Zona   con condiciones de riesgo por avenidas torrenciales      |     Avenidas   Torrenciales    |     Áreas   de Amenaza y Riesgo    |     Zona   con condiciones de riesgo    |     FALSO        |
# |     Con   condiciones de riesgo    |     Zona   con condiciones de riesgo por inundaciones               |     Inundaciones               |     Áreas   de Amenaza y Riesgo    |     Zona   con condiciones de riesgo    |     FALSO        |
# |     N/A                            |     N/A                                                             |     N/A                        |     N/A                            |     N/A                                 |     VERDADERO    |
#
# ---

# %% [markdown]
# ### **Información Catastral**
#
# *   Información Catastral: información que detalla los valores actuales catastrales de los inmuebles rurales.
# >*   Uso Predial: uso principal identificado en campo para el inmueble
# >*   Tipo Predial: tipo principal identificado en campo para el inmueble
# >*   Descripción: descripción del uso y tipo identificado en campo para el inmueble
# >*   Avalúo Lote: avalúo del componente lote
# >*   Avalúo Construcción: avalúo del componente construcción
# >*   Avalúo Total: avalúo total, sumatoria de componente lote y construcción

# %% [markdown]
# ### **Datos**
#
# La fuente de datos para el presente modelo es un dataset el cual contiene la información detallada descrita previamente.
#
#
# |     OBJECTID                  |     ID   catastral del objeto geográfico                          |
# |-------------------------------|-------------------------------------------------------------------|
# |     Perimetro                 |     Perímetro   del objeto geográfico                             |
# |     Area                      |     Área en   metros cuadrados del objeto geográfico              |
# |     CantidadConstrucciones    |     Cantidad   de construcciones independientes en el polígono    |
# |     Area_int                  |     Área en   metros cuadrados sin decimales                      |
# |     X_MAGNAMED                |     Coordenada   X (Longitud)                                     |
# |     Y_MAGNAMED                |     Coordenada   Y (Latitud)                                      |
# |     CS_TF                     |     Valor   dicotómico de la clasificación de suelo               |
# |     EQ_TF                     |     Valor   dicotómico de los equipamientos                       |
# |     H_TF                      |     Valor   dicotómico de la hidrografía                          |
# |     PP_TF                     |     Valor   dicotómico de los planes parciales                    |
# |     PC_TF                     |     Valor   dicotómico de planificación complementaria            |
# |     PP_TF                     |     Valor   dicotómico de protección de producción                |
# |     TR_TF                     |     Valor   dicotómico de tratamientos rurales                    |
# |     UR_TF                     |     Valor   dicotómico de usos rurales                            |
# |     ValorM2                   |     Valor   metro cuadrado del suelo                              |
# |     ZP_TF                     |     Valor   dicotómico de zonas de protección                     |
# |     R_TF                      |     Valor   dicotómico de zonas de riesgo                         |
# |     C_AvaluoLote              |     Valor   del avalúo de lote                                    |
# |     C_AvaluoConstruccion      |     Valor   del avalúo de construcción                            |
# |     C_AvaluoTotal             |     Valor   del avalúo total                                      |

# %% [markdown]
# # **Análisis de datos y módelo**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = 'https://raw.githubusercontent.com/juliancastillo-iudigital/Proyecto_UdeA_Remington_MaCano_IUDigital/main/Data/ModeloAnaliticoV1_01_PeriodDecimals.csv'
df=pd.read_csv(data, sep=';')
df.head()
# Out:
#    OBJECTID   Perimetro          Area  CantidadConstrucciones  Area_int  \
# 0     91946  295.472140   1599.948055                     0.0      1600
# 1     91957  205.925373   2316.148067                     0.0      2316
# 2     91945  487.115922   9601.918111                     0.0      9600
# 3    238500  775.565238  30821.327300                     0.0     30817
# 4    300651  370.176673   6238.883842                     0.0      6238
#
#     X_MAGNAMED   Y_MAGNAMED  CS_TF  EQ_TF  H_TF  ...  PC_TF  PP_TF.1  TR_TF  \
# 0  842251.1945  1186168.125      0      1     0  ...      0        1      0
# 1  842280.4354  1186200.873      0      1     0  ...      0        1      0
# 2  842297.1475  1186129.748      0      1     0  ...      0        1      0
# 3  842377.8440  1185986.364      0      1     1  ...      0        1      0
# 4  842691.9175  1186212.642      0      1     0  ...      0        1      0
#
#    UR_TF  ValorM2  ZP_TF  R_TF  C_AvaluoLote  C_AvaluoConstruccion  \
# ...

# %% [markdown]
# Se detalla el tamaño de los datos al desempaquetar la tupla resultado de `shape`

# %%
a, b = df.shape
print('El tamaño del dataset es: {} filas por {} columnas'.format(a, b))
# Out:
# El tamaño del dataset es: 31893 filas por 21 columnas

# %% [markdown]
# ## **Detalle de la carga de datos**
#
# Los datos son cargados utilizando la librería pandas y se detalla su información con la función `info()`, detallando los siguientes resultados.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31893 entries, 0 to 31892
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   OBJECTID                31893 non-null  int64
#  1   Perimetro               31893 non-null  float64
#  2   Area                    31893 non-null  float64
#  3   CantidadConstrucciones  31803 non-null  float64
#  4   Area_int                31893 non-null  int64
#  5   X_MAGNAMED              31893 non-null  float64
#  6   Y_MAGNAMED              31893 non-null  float64
#  7   CS_TF                   31893 non-null  int64
#  8   EQ_TF                   31893 non-null  int64
#  9   H_TF                    31893 non-null  int64
#  10  PP_TF                   31893 non-null  int64
#  11  PC_TF                   31893 non-null  int64
#  12  PP_TF.1                 31893 non-null  int64
#  13  TR_TF                   31893 non-null  int64
# ...

# %% [markdown]
# ## **Variables y Correlación**
# Las variables numéricas que nos permitirán crear un modelo de regresión logística son las siguientes:
# AreaLote, AreaCons y Valor.
# Como se muestra a continuación AreaCons y Valor presentan una leve correlación la cual es necesaria para relacionar una posible causalidad.
# A continuación, se muestra la tabla de correlación de Pearson de Pandas y su respectivo “heatmap” para valorar la no causalidad de los valores luego de graficar las variables respecto a su representación en las gráficas de relación y los histogramas, donde claramente se muestra la normalidad de las variables AreaCons y AreaLote contra la representación exponencial de la variable Valor.

# %%
corr_mat = df.corr()
corr_mat.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# <style type="text/css">
# #T_a0192_row0_col0, #T_a0192_row1_col1, #T_a0192_row2_col2, #T_a0192_row2_col4, #T_a0192_row3_col3, #T_a0192_row4_col2, #T_a0192_row4_col4, #T_a0192_row5_col5, #T_a0192_row6_col6, #T_a0192_row7_col7, #T_a0192_row8_col8, #T_a0192_row9_col9, #T_a0192_row10_col10, #T_a0192_row11_col11, #T_a0192_row12_col12, #T_a0192_row13_col13, #T_a0192_row14_col14, #T_a0192_row15_col15, #T_a0192_row16_col16, #T_a0192_row17_col17, #T_a0192_row18_col18, #T_a0192_row19_col19, #T_a0192_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a0192_row0_col1, #T_a0192_row0_col19, #T_a0192_row3_col10, #T_a0192_row8_col10, #T_a0192_row10_col20 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_a0192_row0_col2, #T_a0192_row0_col4, #T_a0192_row0_col17, #T_a0192_row12_col17, #T_a0192_row13_col18 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## **Histogramas relacionados con las variables**
#
# Con la función `pandas.hist` crea los histogramas de todas las variables.

# %%
hist = df.hist(bins=30, sharey=False, figsize=(20, 20))

# %% [markdown]
# ## **Utilizaremos el metodo de `cluster` de la libreria `sklearn` usando `KMeans`**

# %%
from sklearn.cluster import KMeans

# %%
plt.scatter(df['X_MAGNAMED'], df['Y_MAGNAMED'])
plt.axis('equal')
plt.show()

# %%
df2 = df.fillna(0)
print(df2)
# Out:
#        OBJECTID    Perimetro          Area  CantidadConstrucciones  Area_int  \
# 0         91946   295.472140  1.599948e+03                     0.0      1600
# 1         91957   205.925373  2.316148e+03                     0.0      2316
# 2         91945   487.115922  9.601918e+03                     0.0      9600
# 3        238500   775.565238  3.082133e+04                     0.0     30817
# 4        300651   370.176673  6.238884e+03                     0.0      6238
# ...         ...          ...           ...                     ...       ...
# 31888    136489  1754.530407  1.564506e+05                     0.0    156399
# 31889    136682  1616.374932  1.135760e+05                     0.0    113539
# 31890    137147  3438.280264  5.200438e+05                     0.0    519872
# 31891    136934  7367.981148  1.777784e+06                     0.0   1777213
# 31892    135927  8530.287795  2.105600e+06                     0.0   2104907
#
# ...

# %%
x = df2.iloc[:]
print(x)
# Out:
#        OBJECTID    Perimetro          Area  CantidadConstrucciones  Area_int  \
# 0         91946   295.472140  1.599948e+03                     0.0      1600
# 1         91957   205.925373  2.316148e+03                     0.0      2316
# 2         91945   487.115922  9.601918e+03                     0.0      9600
# 3        238500   775.565238  3.082133e+04                     0.0     30817
# 4        300651   370.176673  6.238884e+03                     0.0      6238
# ...         ...          ...           ...                     ...       ...
# 31888    136489  1754.530407  1.564506e+05                     0.0    156399
# 31889    136682  1616.374932  1.135760e+05                     0.0    113539
# 31890    137147  3438.280264  5.200438e+05                     0.0    519872
# 31891    136934  7367.981148  1.777784e+06                     0.0   1777213
# 31892    135927  8530.287795  2.105600e+06                     0.0   2104907
#
# ...

# %%
distortions = []
K = range(1,20)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(x)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distorsion')
plt.title('El método del codo pinta el k optimo')
plt.show()

# %%
kmeans = KMeans(10) #De acuerdo con la grafica anterior el optimo se estabiliza en 10 clusters
kmeans.fit(x)
# Out:
# KMeans(n_clusters=10)

# %%
gruposIdentificados = kmeans.fit_predict(x)
gruposIdentificados
# Out:
# array([8, 8, 8, ..., 0, 3, 3], dtype=int32)

# %%
datosAGrupados = df2.copy()
datosAGrupados['Cluster'] = gruposIdentificados
datosAGrupados
# Out:
#        OBJECTID    Perimetro          Area  CantidadConstrucciones  Area_int  \
# 0         91946   295.472140  1.599948e+03                     0.0      1600
# 1         91957   205.925373  2.316148e+03                     0.0      2316
# 2         91945   487.115922  9.601918e+03                     0.0      9600
# 3        238500   775.565238  3.082133e+04                     0.0     30817
# 4        300651   370.176673  6.238884e+03                     0.0      6238
# ...         ...          ...           ...                     ...       ...
# 31888    136489  1754.530407  1.564506e+05                     0.0    156399
# 31889    136682  1616.374932  1.135760e+05                     0.0    113539
# 31890    137147  3438.280264  5.200438e+05                     0.0    519872
# 31891    136934  7367.981148  1.777784e+06                     0.0   1777213
# 31892    135927  8530.287795  2.105600e+06                     0.0   2104907
#
# ...

# %%
plt.scatter(datosAGrupados['X_MAGNAMED'],
            datosAGrupados['Y_MAGNAMED'],
            c=datosAGrupados['Cluster'],
            cmap='rainbow')
plt.grid(axis= 'both', color='b', alpha=0.5)
plt.axis('equal')
plt.show()

# %%
#Exportamos los datos
datosAGrupados.to_excel('/content/ModeloFinal.xlsx')
